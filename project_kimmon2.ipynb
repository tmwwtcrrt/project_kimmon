# %% [markdown]
# <a href="https://colab.research.google.com/github/tmwwtcrrt/project_kimmon/blob/main/project_kimmon2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Setup

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-376-gbcd88eaf Python-3.10.12 torch-2.4.1+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.2/107.7 GB disk)

# %% [markdown]
# Test Detect

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-376-gbcd88eaf Python-3.10.12 torch-2.4.1+cu121 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 127MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 377.7ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 299.3ms
# Speed: 2.3ms pre-process, 338.5ms inference, 20.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# เทรน

# %% [markdown]
# แก้ไฟล์ ใน data/kimmon.yaml
#
#
# train: /content/drive/MyDrive/pj_kimmon/train
# val: /content/drive/MyDrive/pj_kimmon/valid
# test: /content/drive/MyDrive/pj_kimmon/test
#
# # Classes
# names:
#   0: cardv1
#   1: cardv2
#   2: cardv3
#   3: cardv4
#   4: dollv1
#   5: dollv2
#   6: dollv3
#   7: dollv4

# %% [markdown]
# แก้ไข models/yolov5s.yaml
#
# size label
# nc: 8

# %% [markdown]
# จำนวนรูปที่ใช้เทรนทั้งหมดมี 4855 รูป
#
# จะแบ่งเป็น 3 set โดยใช้อัตราส่วน 80:10:10 ดังนี้
#
# **train set**: 4855 * 0.8 = 3884 รูป
#
# **valid set**: 4855 * 0.1 = 485.5 ปัดเศษขึ้นเป็น 486 รูป
#
# **test set**: 4855 * 0.1 = 485.5 ปัดเศษขึ้นเป็น 486 รูป

# %%
# !python train.py --img 640 --epochs 40 --data kimmon.yaml --weights yolov5s.pt
# Out:
# Streaming output truncated to the last 5000 lines.
#       29/39      4.55G    0.01784    0.01585   0.002106         68        640:  86% 209/243 [02:11<00:28,  1.20it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/39      4.55G    0.01784    0.01586   0.002104         76        640:  86% 210/243 [02:11<00:21,  1.55it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/39      4.55G    0.01783    0.01584   0.002107         70        640:  87% 211/243 [02:12<00:22,  1.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %% [markdown]
# ทดสอบการเทรน valid set

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/project_kimmon/valid/images
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/project_kimmon/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-375-g79b7336f Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7031701 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/486 /content/drive/MyDrive/project_kimmon/valid/images/100_jpg.rf.28d945a1a3883679f4df01d3315ec7bd.jpg: 640x640 1 cardv4, 11.6ms
# ...

# %% [markdown]
# ทดสอบการเทรน test set

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/project_kimmon/test/images
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/project_kimmon/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-376-gbcd88eaf Python-3.10.12 torch-2.4.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7031701 parameters, 0 gradients, 15.8 GFLOPs
# image 1/486 /content/drive/MyDrive/project_kimmon/test/images/100_jpg.rf.d539c518bfa7b5b7afc655da6402dc7f.jpg: 640x640 1 cardv4, 429.2ms
# image 2/486 /content/drive/MyDrive/project_kimmon/test/images/101_jpg.rf.df19a11ef4c4ea7ddc5ced363336298b.jpg: 640x640 1 cardv1, 414.8ms
# ...

# %% [markdown]
# ทดสอบผล test

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/yolov5/test/all.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/yolov5/test/all.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-376-gbcd88eaf Python-3.10.12 torch-2.4.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7031701 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/test/all.jpg: 480x640 1 cardv2, 1 dollv1, 6 dollv2s, 9 dollv3s, 4 dollv4s, 394.1ms
# Speed: 1.6ms pre-process, 394.1ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp17

# %% [markdown]
# โหลดfolderผลลัพธ์

# %%
import shutil

folder_path = '/content/yolov5/runs/detect/exp2'

output_filename = 'result_exp3'

shutil.make_archive(output_filename, 'zip', folder_path)
# Out:
# '/content/yolov5/result_exp3.zip'

# %%
from google.colab import files

files.download(output_filename + '.zip')
